    (66,1024,0,2,18.42256566332959,0.04536922437569307,0.061373249897045325,0.0037666758029251735,18.148052097943165),
]

cols = ["expiry","window_size","normalize","freq_input","mape","mae","rmse","mse","mase"]
df_h5 = pd.DataFrame(rows_h5, columns=cols)
df_h22 = pd.DataFrame(rows_h22, columns=cols)
df_h66 = pd.DataFrame(rows_h66, columns=cols)

# Prepare data for box plots - h=5 (1w)
mape_data_h5 = [df_h5[df_h5['freq_input'] == f]['mape'].values for f in [0, 1, 2]]
frequency_labels = ['f=0', 'f=1', 'f=2']

# Prepare data for box plots - h=22 (1m)
mape_data_h22 = [df_h22[df_h22['freq_input'] == f]['mape'].values for f in [0, 1, 2]]

# Prepare data for box plots - h=66 (3m)
mape_data_h66 = [df_h66[df_h66['freq_input'] == f]['mape'].values for f in [0, 1, 2]]

# Create 3x1 subplot figure
fig, axes = plt.subplots(3, 1, figsize=(8, 12))

# Plot at position (0,0) - h=5 (1w)
ax = axes[0]
ax.boxplot(mape_data_h5, labels=frequency_labels)
ax.set_xlabel("Frequency (f)")
ax.set_ylabel("MAPE (%)")
ax.set_title("h=5 (1w)")
ax.grid(True, alpha=0.3)

# Plot at position (1,0) - h=22 (1m)
ax = axes[1]
ax.boxplot(mape_data_h22, labels=frequency_labels)
ax.set_xlabel("Frequency (f)")
ax.set_ylabel("MAPE (%)")
ax.set_title("h=22 (1m)")
ax.grid(True, alpha=0.3)

# Plot at position (2,0) - h=66 (3m)
ax = axes[2]
ax.boxplot(mape_data_h66, labels=frequency_labels)
ax.set_xlabel("Frequency (f)")
ax.set_ylabel("MAPE (%)")
ax.set_title("h=66 (3m)")
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print summary statistics
print("Summary Statistics by Frequency:")
print("\nh=5 (1w):")
for i, f in enumerate([0, 1, 2]):
    data = df_h5[df_h5['freq_input'] == f]['mape']
    print(f"  f={f}: Mean={data.mean():.3f}, Std={data.std():.3f}, N={len(data)}")

print("\nh=22 (1m):")
for i, f in enumerate([0, 1, 2]):
    data = df_h22[df_h22['freq_input'] == f]['mape']
    print(f"  f={f}: Mean={data.mean():.3f}, Std={data.std():.3f}, N={len(data)}")

print("\nh=66 (3m):")
for i, f in enumerate([0, 1, 2]):
    data = df_h66[df_h66['freq_input'] == f]['mape']
    print(f"  f={f}: Mean={data.mean():.3f}, Std={data.std():.3f}, N={len(data)}")
# Out:
# C:\Users\PanSt\AppData\Local\Temp\ipykernel_63144\2585799760.py:135: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(mape_data_h5, labels=frequency_labels)
# C:\Users\PanSt\AppData\Local\Temp\ipykernel_63144\2585799760.py:143: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(mape_data_h22, labels=frequency_labels)
# C:\Users\PanSt\AppData\Local\Temp\ipykernel_63144\2585799760.py:151: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(mape_data_h66, labels=frequency_labels)
# Summary Statistics by Frequency:
#
# h=5 (1w):
#   f=0: Mean=64.363, Std=8.057, N=12
# ...

# %%
df.groupby(by='freq_input').std()
# Out:
#             expiry  window_size  normalize       mape       mae      rmse  \
# freq_input
# 0              0.0   361.910084   0.522233   8.056824  0.014292  0.017619
# 1              0.0   361.910084   0.522233   6.909574  0.008340  0.011148
# 2              0.0   361.910084   0.522233  15.553007  0.018992  0.827711
#
#                  mse      mase
# freq_input
# 0           0.005393  0.469670
# 1           0.003247  0.318511
# 2           1.970797  0.572936
